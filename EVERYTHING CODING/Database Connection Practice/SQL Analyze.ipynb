# %% [markdown]
# # Connecting to Database

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine("mysql+mysqlconnector://root:jys502943@localhost/practice")

# %%
db = engine.connect()

# %%
chicago_socioeconomic_data = pd.read_csv('https://data.cityofchicago.org/resource/jcxq-k9xf.csv')

# %%
chicago_socioeconomic_data.columns
# Out:
# Index(['ca', 'community_area_name', 'percent_of_housing_crowded',
#        'percent_households_below_poverty', 'percent_aged_16_unemployed',
#        'percent_aged_25_without_high_school_diploma',
#        'percent_aged_under_18_or_over_64', 'per_capita_income_',
#        'hardship_index'],
#       dtype='object')

# %%
chicago_socioeconomic_data
# Out:
#       ca community_area_name  percent_of_housing_crowded  \
# 0    1.0         Rogers Park                         7.7
# 1    2.0          West Ridge                         7.8
# 2    3.0              Uptown                         3.8
# 3    4.0      Lincoln Square                         3.4
# 4    5.0        North Center                         0.3
# ..   ...                 ...                         ...
# 73  74.0     Mount Greenwood                         1.0
# 74  75.0         Morgan Park                         0.8
# 75  76.0              O'Hare                         3.6
# 76  77.0           Edgewater                         4.1
# 77   NaN             CHICAGO                         4.7
#
#     percent_households_below_poverty  percent_aged_16_unemployed  \
# 0                               23.6                         8.7
# 1                               17.2                         8.8
# 2                               24.0                         8.9
# ...

# %%
chicago_socioeconomic_data.dtypes
# Out:
# ca                                             float64
# community_area_name                             object
# percent_of_housing_crowded                     float64
# percent_households_below_poverty               float64
# percent_aged_16_unemployed                     float64
# percent_aged_25_without_high_school_diploma    float64
# percent_aged_under_18_or_over_64               float64
# per_capita_income_                               int64
# hardship_index                                 float64
# dtype: object

# %%
query = '''CREATE TABLE IF NOT EXISTS chicago_socioeconomic_data 
(ca int PRIMARY KEY, 
community_area_name VARCHAR(40), 
percent_of_housing_crowded DECIMAL, 
percent_households_below_poverty DECIMAL, 
percent_aged_16_unemployed DECIMAL, 
percent_aged_25_without_high_school_diploma DECIMAL, 
percent_aged_under_18_or_over_64 DECIMAL, 
per_capita_income_ INT, 
hardship_index INT)'''

# %%
db.execute(query)

# %%
db.execute('CREATE TABLE IF NOT EXISTS chicago_socioeconomic_data (cja int PRIMARY KEY, community_area_name VARCHAR(40), percent_of_housing_crowded DECIMAL, percent_households_below_poverty DECIMAL, percent_aged_16_unemployed DECIMAL, percent_aged_25_without_high_school_diploma DECIMAL, percent_aged_under_18_or_over_64 DECIMAL, per_capita_income_ INT, hardship_index INT)')

# %%
chicago_socioeconomic_data.to_sql(con=engine,name='chicago_socioeconomic_data',if_exists='replace',index=False)

# %%
output = db.execute('SELECT * FROM chicago_socioeconomic_data')

# %%
for x in output:
    print(x)
# Out:
# (1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0)
# (2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0)
# (3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0)
# (4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0)
# (5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0)
# (6.0, 'Lake View', 1.1, 11.4, 4.7, 2.6, 17.0, 60058, 5.0)
# (7.0, 'Lincoln Park', 0.8, 12.3, 5.1, 3.6, 21.5, 71551, 2.0)
# (8.0, 'Near North Side', 1.9, 12.9, 7.0, 2.5, 22.6, 88669, 1.0)
# (9.0, 'Edison Park', 1.1, 3.3, 6.5, 7.4, 35.3, 40959, 8.0)
# (10.0, 'Norwood Park', 2.0, 5.4, 9.0, 11.5, 39.5, 32875, 21.0)
# (11.0, 'Jefferson Park', 2.7, 8.6, 12.4, 13.4, 35.5, 27751, 25.0)
# (12.0, 'Forest Glen', 1.1, 7.5, 6.8, 4.9, 40.5, 44164, 11.0)
# (13.0, 'North Park', 3.9, 13.2, 9.9, 14.4, 39.0, 26576, 33.0)
# (14.0, 'Albany Park', 11.3, 19.2, 10.0, 32.9, 32.0, 21323, 53.0)
# (15.0, 'Portage Park', 4.1, 11.6, 12.6, 19.3, 34.0, 24336, 35.0)
# ...

# %%
pdf_chicago_socioeconomic_data = pd.read_sql('SELECT * FROM chicago_socioeconomic_data', db)

# %%
pdf_chicago_socioeconomic_data
# Out:
#       ca community_area_name  percent_of_housing_crowded  \
# 0    1.0         Rogers Park                         7.7
# 1    2.0          West Ridge                         7.8
# 2    3.0              Uptown                         3.8
# 3    4.0      Lincoln Square                         3.4
# 4    5.0        North Center                         0.3
# ..   ...                 ...                         ...
# 73  74.0     Mount Greenwood                         1.0
# 74  75.0         Morgan Park                         0.8
# 75  76.0              O'Hare                         3.6
# 76  77.0           Edgewater                         4.1
# 77   NaN             CHICAGO                         4.7
#
#     percent_households_below_poverty  percent_aged_16_unemployed  \
# 0                               23.6                         8.7
# 1                               17.2                         8.8
# 2                               24.0                         8.9
# ...

# %% [markdown]
# # Creating own table

# %%
datas = {'product_name': ['Computer','Tablet','Monitor','Printer'],
        'price': [900,300,450,150]
        }

# %%
products = pd.DataFrame(datas, columns= ['product_name','price'])
print (products)
# Out:
#   product_name  price
# 0     Computer    900
# 1       Tablet    300
# 2      Monitor    450
# 3      Printer    150

# %%
db.execute('CREATE TABLE IF NOT EXISTS products_df (product_name varchar(50), price int)')

# %%
products.to_sql(con=engine,name='products_df',if_exists='replace',index=False)

# %%
db.close()

# %% [markdown]
# # To retrieve table

# %%
df = pd.read_sql_query('SELECT * FROM employees', db)
print(df)

# %% [markdown]
# # SQL MAGIC
# Although SQL magic simplifies working with databases, it has some limitations. For example, unlike DB-API, there are no explicit methods to close a connection and free up resources.

# %%
pip install ipython-sql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysqlclient
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %%
# %sql mysql+mysqldb://root:jys502943@localhost/Practice

# %%
# %%sql
# SELECT * FROM employees
# Out:
#  * mysql+mysqldb://root:***@localhost/Practice
# 10 rows affected.
# [('E1001', 'John', 'Thomas', '123456', datetime.date(1976, 1, 9), 'M', '5631 Rice, OakPark,IL', '100', Decimal('100000.00'), '30001', '2'),
#  ('E1002', 'Alice', 'James', '123457', datetime.date(1972, 7, 31), 'F', '980 Berry ln, Elgin,IL', '200', Decimal('80000.00'), '30002', '5'),
#  ('E1003', 'Steve', 'Wells', '123458', datetime.date(1980, 8, 10), 'M', '291 Springs, Gary,IL', '300', Decimal('50000.00'), '30002', '5'),
#  ('E1004', 'Santosh', 'Kumar', '123459', datetime.date(1985, 7, 20), 'M', '511 Aurora Av, Aurora,IL', '400', Decimal('60000.00'), '30004', '5'),
#  ('E1005', 'Ahmed', 'Hussain', '123410', datetime.date(1981, 1, 4), 'M', '216 Oak Tree, Geneva,IL', '500', Decimal('70000.00'), '30001', '2'),
#  ('E1006', 'Nancy', 'Allen', '123411', datetime.date(1978, 2, 6), 'F', '111 Green Pl, Elgin,IL', '600', Decimal('90000.00'), '30001', '2'),
# ...
