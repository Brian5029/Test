# %%
import requests
import pandas as pd
import time

# %%
API_KEY = 'AIzaSyDcgWGHfjfAm-hFomj-GHkwlsp1ZlWeASA'
CHANNEL_ID = 'UC1fLEeYICmo3O9cUsqIi7HA'

# %%
#make API call(retrieiving data)
pageToken =""
url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken
response = requests.get(url).json()

# %%
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/search?key=AIzaSyDcgWGHfjfAm-hFomj-GHkwlsp1ZlWeASA&channelId=UC1fLEeYICmo3O9cUsqIi7HA&part=snippet,id&order=date&maxResults=10000

# %%
response['items']
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': '7qq4jfdCn_BzLBQV-JYR-qbbjTM',
#   'id': {'kind': 'youtube#video', 'videoId': 'h_vSuWza5Ss'},
#   'snippet': {'publishedAt': '2021-12-29T15:00:18Z',
#    'channelId': 'UC1fLEeYICmo3O9cUsqIi7HA',
#    'title': 'Donating Money To Coding Streamers',
#    'description': 'Install Raid for Free ✓ IOS/ANDROID/PC: https://pl.go-ga.me/5qbw4lch and get a special starter pack Available only for the next ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/h_vSuWza5Ss/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/h_vSuWza5Ss/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/h_vSuWza5Ss/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Nick White',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-12-29T15:00:18Z'}},
#  {'kind': 'youtube#searchResult',
# ...

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '7qq4jfdCn_BzLBQV-JYR-qbbjTM',
#  'id': {'kind': 'youtube#video', 'videoId': 'h_vSuWza5Ss'},
#  'snippet': {'publishedAt': '2021-12-29T15:00:18Z',
#   'channelId': 'UC1fLEeYICmo3O9cUsqIi7HA',
#   'title': 'Donating Money To Coding Streamers',
#   'description': 'Install Raid for Free ✓ IOS/ANDROID/PC: https://pl.go-ga.me/5qbw4lch and get a special starter pack Available only for the next ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/h_vSuWza5Ss/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/h_vSuWza5Ss/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/h_vSuWza5Ss/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Nick White',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2021-12-29T15:00:18Z'}}

# %%
video_id = response['items'][0]['id']['videoId']
video_id
# Out:
# 'h_vSuWza5Ss'

# %%
video_title = response['items'][0]['snippet']['title']
video_title
# Out:
# 'Donating Money To Coding Streamers'

# %%
upload_date = response['items'][0]['snippet']['publishedAt']
upload_date
# Out:
# '2021-12-29T15:00:18Z'

# %%
upload_date = str(upload_date).split('T')[0]
upload_date
# Out:
# '2021-12-29'

# %%
#looping through the response and getting specific data from youtube videos only
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        upload_date = video['snippet']['publishedAt']
        upload_date = str(upload_date).split('T')[0]
        
        print(video_id)
        print(video_title)
        print(upload_date)
# Out:
# h_vSuWza5Ss
# Donating Money To Coding Streamers
# 2021-12-29
# dEnH69thZm0
# Tech Burnout
# 2021-12-04
# b7SJKhinrQQ
# Giving Harvard Students Money If They Solve THIS Coding Question
# 2021-11-17
# NpU1sZ9y0Oo
# The Dark Side Of The Tech Industry
# 2021-10-29
# rskXx4mNBNQ
# How I Spend My Software Engineer Income (6 Figures)
# 2021-10-22
# Rl-SWiuZ24o
# How I would learn to code (if I could start over)
# 2021-10-15
# utgrxaKgty0
# A Day in the Life of a Software Engineer Working From Home
# 2021-09-30
# xjX6dwRXpcw
# We Told Programming Jokes In New York City!
# 2021-08-19
# WDuZ_S_9vLg
# Solve This Coding Question To Win $200
# 2021-07-19
# spS2vVHvsvg
# Improve Your Programming Skills  - The Ballmer Peak
# 2021-07-06
# _DvSIoQKBac
# Solve This Coding Question To Win $100
# 2021-07-02
# a7nWwYAp8r8
# How I Make $50/Hour Freelance Programming on Upwork!
# 2021-06-24
# JEyX6GD0SX0
# Every Coding Interview Ever
# 2021-06-22
# w8Kkoe37IxU
# Apologizing To Tech Lead
# 2021-05-31
# ...

# %%
# retrieving specific video stats
url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
response_video_stats = requests.get(url_video_stats).json()
response_video_stats
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'IiPNHkbEILqkYEkZEBFvHgVxJyQ',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'p6bVQhn4pq-sRnRUGqjHZ5h9BSs',
#    'id': 'vvP5ZTIGdl8',
#    'statistics': {'viewCount': '27864',
#     'likeCount': '1182',
#     'favoriteCount': '0'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %% [markdown]
# # Clean Overview

# %%
API_KEY = 'AIzaSyDcgWGHfjfAm-hFomj-GHkwlsp1ZlWeASA'
CHANNEL_ID = 'UC1fLEeYICmo3O9cUsqIi7HA'

# %%
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","favorite_count"])
df
# Out:
# Empty DataFrame
# Columns: [video_id, video_title, upload_date, view_count, like_count, favorite_count]
# Index: []

# %%
#collecting view, like, favorite, counts
def get_video_details(video_id):
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()
    
    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    favorite_count = response_video_stats['items'][0]['statistics']['favoriteCount']
    
    return view_count, like_count, favorite_count

# %%
def get_videos(df):
    #make API call
    pageToken =""
    url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken

    response = requests.get(url).json()
    time.sleep(1) #waiting 1 second to give time to retrieve data for forloop

    for video in response['items']:
        if video['id']['kind'] == 'youtube#video':
            video_id = video['id']['videoId']
            video_title = video['snippet']['title']
            upload_date = video['snippet']['publishedAt']
            upload_date = str(upload_date).split('T')[0]

            view_count, like_count, favorite_count = get_video_details(video_id)

            #save data in pandas df
            df = df.append({'video_id': video_id,
                          'video_title':video_title,
                          'upload_date':upload_date,
                          'view_count':view_count,
                          'like_count':like_count,
                          'favorite_count':favorite_count
                         },ignore_index=True)
    return df

# %%
df = get_videos(df)
df
# Out:
#         video_id                                        video_title  \
# 0    h_vSuWza5Ss                 Donating Money To Coding Streamers
# 1    dEnH69thZm0                                       Tech Burnout
# 2    b7SJKhinrQQ  Giving Harvard Students Money If They Solve TH...
# 3    NpU1sZ9y0Oo                 The Dark Side Of The Tech Industry
# 4    rskXx4mNBNQ  How I Spend My Software Engineer Income (6 Fig...
# ..           ...                                                ...
# 192  9-ubSA9GA3o   How I Got Good at Algorithms and Data Structures
# 193  jnoVtCKECmQ  Kadane&#39;s Algorithm - Maximum Sum Subarray ...
# 194  vvP5ZTIGdl8              Build The Perfect Developer Portfolio
# 195  J5YPh5ur-ws                        Coding Google in 60 Seconds
# 196  q4-n4KCqC8k  Technical Interview with a Software Engineer -...
#
#     upload_date view_count like_count favorite_count
# 0    2021-12-29       5726        388              0
# ...
